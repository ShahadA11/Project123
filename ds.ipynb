# %%
import pandas as pd

# Load the dataset
data = pd.read_csv('Global health coffee.csv')

#modify 150 to 140
sample = data.sample(n=140, random_state=42)

#Define a function for descriptive statistics
def custom_descriptive_stats(series):
    stats = {
        'Count': series.count(),
        'Mean': series.mean(),
        'Median': series.median(),
        'Min': series.min(),
        'Max': series.max(),
        'Standard Deviation': series.std(),
        'Variance': series.var(),
        'Skewness': series.skew(),
        'Kurtosis': series.kurt(),
        '25% Quantile': series.quantile(0.25),
        '50% Quantile (Median)': series.quantile(0.5),
        '75% Quantile': series.quantile(0.75)
    }
    return stats

# Apply the function to the dependent variable 'Caffeine_mg'
caffeine_stats = custom_descriptive_stats(sample['Caffeine_mg'])

#Display the result
print("\nDescriptive Statistics for 'Caffeine_mg' (Sample of 140 rows):\n")
for key, value in caffeine_stats.items():
    print(f"{key:30}: {value:.2f}")
# Out:
# Descriptive Statistics for 'Caffeine_mg' (Sample of 140 rows):
#
# Count                         : 140.00
# Mean                          : 231.03
# Median                        : 228.90
# Min                           : 0.00
# Max                           : 613.70
# Standard Deviation            : 145.58
# Variance                      : 21192.53
# Skewness                      : 0.38
# Kurtosis                      : -0.38
# 25% Quantile                  : 130.38
# 50% Quantile (Median)         : 228.90
# 75% Quantile                  : 321.25
